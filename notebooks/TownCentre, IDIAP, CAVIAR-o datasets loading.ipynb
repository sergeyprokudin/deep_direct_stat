# %% [markdown]
# ### TownCentre dataset
#
# http://www.robots.ox.ac.uk/~lav/Papers/benfold_reid_cvpr2011/

# %%
from datasets.towncentre import load_towncentre

# %%
(xtr, ytr, img_names_tr), (xval, yval, img_names_val), (xte, yte, img_names_te) = load_towncentre('../data/TownCentre.pkl.gz',
                                                              canonical_split=True,
                                                              verbose=1)
# Out:
# Number of train samples: 6916
# Number of validation samples: 874
# Number of test samples: 904

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

fid = np.random.randint(xtr.shape[0])
plt.imshow(xtr[fid])
plt.show()
fid = np.random.randint(xtr.shape[0])
plt.imshow(xtr[fid])
plt.show()
fid = np.random.randint(xtr.shape[0])
plt.imshow(xtr[fid])
plt.show()

# %% [markdown]
# ### CAVIAR dataset
#
# http://groups.inf.ed.ac.uk/vision/CAVIAR/CAVIARDATA1/

# %%
from datasets.caviar import load_caviar

# %%
(xtr, ytr_deg, info_tr), (xval, yval_deg, info_val), (xte, yte_deg, info_te) = load_caviar('../data/CAVIAR-o.pkl.gz', val_split=0.5, canonical_split=True, verbose=0)

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

fid = np.random.randint(xtr.shape[0])
plt.imshow(xtr[fid])
plt.show()
fid = np.random.randint(xtr.shape[0])
plt.imshow(xtr[fid])
plt.show()
fid = np.random.randint(xtr.shape[0])
plt.imshow(xtr[fid])
plt.show()
